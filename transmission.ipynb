# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_transmission=pd.read_csv("C:\\Users\\ACER\\OneDrive\\Desktop\\luminar\\ml_project\\final\\datasets\\transmission_health.csv")
df_transmission
# Out:
#       Car_ID  Gear_Slip_Frequency  Clutch_Wear_Percentage  Transmission_Temp  \
# 0          1                  2.0                0.969183          80.176541
# 1          2                  1.0               20.007866         114.908910
# 2          3                  1.0               35.398912                NaN
# 3          4                  1.0               26.760596         108.923693
# 4          5                  1.0               60.126526          89.927151
# ...      ...                  ...                     ...                ...
# 5995    5996                  1.0               96.328427          83.120055
# 5996    5997                  3.0                     NaN          76.351953
# 5997    5998                  1.0                4.736433         110.614863
# 5998    5999                  1.0               37.098033          97.467098
# 5999    6000                  4.0               27.905216          82.194550
#
#       Axle_Wear_Score  Transmission_Remaining_Years
# 0                 NaN                      6.452474
# 1            9.340959                      5.263608
# 2            2.338095                      8.562154
# 3            6.179788                      6.315481
# 4            3.022204                      6.190339
# ...               ...                           ...
# 5995         2.706725                      4.702870
# 5996         9.077469                      5.426059
# 5997         2.025530                      8.481902
# 5998         4.786674                      6.214984
# 5999         7.990678                      3.078508
#
# [6000 rows x 6 columns]

# %%
df_transmission.head()
# Out:
#    Car_ID  Gear_Slip_Frequency  Clutch_Wear_Percentage  Transmission_Temp  \
# 0       1                  2.0                0.969183          80.176541
# 1       2                  1.0               20.007866         114.908910
# 2       3                  1.0               35.398912                NaN
# 3       4                  1.0               26.760596         108.923693
# 4       5                  1.0               60.126526          89.927151
#
#    Axle_Wear_Score  Transmission_Remaining_Years
# 0              NaN                      6.452474
# 1         9.340959                      5.263608
# 2         2.338095                      8.562154
# 3         6.179788                      6.315481
# 4         3.022204                      6.190339

# %%
df_transmission.tail()
# Out:
#       Car_ID  Gear_Slip_Frequency  Clutch_Wear_Percentage  Transmission_Temp  \
# 5995    5996                  1.0               96.328427          83.120055
# 5996    5997                  3.0                     NaN          76.351953
# 5997    5998                  1.0                4.736433         110.614863
# 5998    5999                  1.0               37.098033          97.467098
# 5999    6000                  4.0               27.905216          82.194550
#
#       Axle_Wear_Score  Transmission_Remaining_Years
# 5995         2.706725                      4.702870
# 5996         9.077469                      5.426059
# 5997         2.025530                      8.481902
# 5998         4.786674                      6.214984
# 5999         7.990678                      3.078508

# %%
df_transmission.isna().sum()
# Out:
# Car_ID                            0
# Gear_Slip_Frequency             551
# Clutch_Wear_Percentage          417
# Transmission_Temp               513
# Axle_Wear_Score                 486
# Transmission_Remaining_Years      0
# dtype: int64

# %%
df_transmission.dtypes
# Out:
# Car_ID                            int64
# Gear_Slip_Frequency             float64
# Clutch_Wear_Percentage          float64
# Transmission_Temp               float64
# Axle_Wear_Score                 float64
# Transmission_Remaining_Years    float64
# dtype: object

# %%
df_transmission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Car_ID                        6000 non-null   int64
#  1   Gear_Slip_Frequency           5449 non-null   float64
#  2   Clutch_Wear_Percentage        5583 non-null   float64
#  3   Transmission_Temp             5487 non-null   float64
#  4   Axle_Wear_Score               5514 non-null   float64
#  5   Transmission_Remaining_Years  6000 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 281.4 KB

# %%
df_transmission.describe()
# Out:
#             Car_ID  Gear_Slip_Frequency  Clutch_Wear_Percentage  \
# count  6000.000000          5449.000000             5583.000000
# mean   3000.500000             2.489072               52.449539
# std    1732.195139             4.196852               30.188513
# min       1.000000             0.000000                0.001413
# 25%    1500.750000             1.000000               26.140310
# 50%    3000.500000             1.000000               52.117112
# 75%    4500.250000             2.000000               79.663700
# max    6000.000000            24.993833               99.996021
#
#        Transmission_Temp  Axle_Wear_Score  Transmission_Remaining_Years
# count        5487.000000      5514.000000                   6000.000000
# mean           93.474825         4.773156                      5.803077
# std            19.225194         2.807059                      2.562493
# min            65.002019         0.000847                      0.100000
# 25%            78.673854         2.362593                      3.981940
# 50%            91.965802         4.696574                      5.816390
# 75%           105.029519         7.220554                      7.633026
# max           159.985004         9.998383                     12.000000

# %%
plt.hist(df_transmission["Transmission_Remaining_Years"], bins=40)
plt.xlabel("Transmission Remaining Years")
plt.ylabel("Count")
plt.title("Transmission Remaining Life Distribution")
plt.show()

# %%
plt.scatter(
    df_transmission["Gear_Slip_Frequency"],
    df_transmission["Transmission_Remaining_Years"],
    alpha=0.5
)
plt.xlabel("Gear Slip Frequency")
plt.ylabel("Transmission Remaining Years")
plt.title("Gear Slips vs Transmission Life")
plt.show()

# %%
features = [
    "Gear_Slip_Frequency",
    "Clutch_Wear_Percentage",
    "Transmission_Temp",
    "Axle_Wear_Score"
]

for col in features:
    plt.boxplot(df_transmission[col].dropna())
    plt.title(col)
    plt.show()

# %%
feature_cols = [
    "Clutch_Wear_Percentage",
    "Transmission_Temp",
    "Axle_Wear_Score"
    
]
df_transmission['Gear_Slip_Frequency']=df_transmission['Gear_Slip_Frequency'].fillna(df_transmission['Gear_Slip_Frequency'].mode()[0])
for col in feature_cols:
    df_transmission[col] = df_transmission[col].fillna(df_transmission[col].median())

# %%
df_transmission.isna().sum()
# Out:
# Car_ID                          0
# Gear_Slip_Frequency             0
# Clutch_Wear_Percentage          0
# Transmission_Temp               0
# Axle_Wear_Score                 0
# Transmission_Remaining_Years    0
# dtype: int64

# %%
x = df_transmission.drop(
    columns=["Transmission_Remaining_Years", "Car_ID"]
)
y = df_transmission["Transmission_Remaining_Years"]

# %%
for col in x.columns:
    lower = x[col].quantile(0.01)
    upper = x[col].quantile(0.99)
    x[col] = x[col].clip(lower, upper)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.3,
    random_state=42
)

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(
    n_estimators=250,
    max_depth=9,
    min_samples_leaf=12,
    random_state=42
)

model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
print("MAE :", mean_absolute_error(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
print("R2  :", r2_score(y_test, y_pred))
# Out:
# MAE : 1.0113718845243982
# RMSE: 1.3577550734629853
# R2  : 0.7171085864355768

# %%
print("Train R2:", model.score(x_train, y_train))
print("Test R2 :", model.score(x_test, y_test))
# Out:
# Train R2: 0.7971282438761936
# Test R2 : 0.7171085864355768

# %%
import joblib

joblib.dump(model, "transmission_model.pkl")
# Out:
# ['transmission_model.pkl']
